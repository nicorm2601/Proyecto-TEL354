# %%
from pysentimiento import create_analyzer
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("tweets.csv")

# %%
df
# Out:
#                  user                                               text  \
# 0    @joseantoniokast  Si un canal de televisión puede establecer la ...
# 1    @DipRepublicanos  ¿Cuál fue su aporte? ¿Por qué no se conocen lo...
# 2    @joseantoniokast  Otra voltereta más. El “Perro Matapacos” ya no...
# 3    @joseantoniokast  Llegaron tarde a la emergencia. Montaron un sh...
# 4    @joseantoniokast  En los cerros de Viña del Mar junto a nuestro ...
# ..                ...                                                ...
# 500     @ClaudioCofr4  Le robaron a OTRO PACO armas... realmente la i...
# 501       @MiTurno143  Cuando JIN salga del servicio militar 😂 #bts #...
# 502    @360radiochile  Alanis Morrissette y su disco unplugged comple...
# 503    @360radiochile  3 horas de música electrónica bailable sin pau...
# 504       @xuxumeitor  A propósito del #ServicioMilitar y el intento ...
#
#                            date
# 0    May 11, 2024 · 8:11 PM UTC
# 1    May 11, 2024 · 3:52 PM UTC
# 2    May 11, 2024 · 2:35 PM UTC
# 3    May 11, 2024 · 1:44 AM UTC
# 4    May 10, 2024 · 7:54 PM UTC
# ..                          ...
# 500  May 10, 2024 · 2:15 PM UTC
# 501  May 10, 2024 · 6:07 PM UTC
# 502  May 10, 2024 · 2:07 PM UTC
# 503  May 10, 2024 · 4:22 PM UTC
# 504  May 11, 2024 · 8:45 PM UTC
#
# [505 rows x 3 columns]

# %%
analyzer = create_analyzer(task="emotion", lang="es")

df = df.dropna(subset=['text'])

def get_main_emotion(text):
    result = analyzer.predict(text)
    main_emotion = max(result.probas, key=result.probas.get)
    
    return main_emotion

df['emotion'] = df['text'].apply(get_main_emotion)
# Out:
# c:\Users\Nicolas\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
df
# Out:
#                  user                                               text  \
# 0    @joseantoniokast  Si un canal de televisión puede establecer la ...
# 1    @DipRepublicanos  ¿Cuál fue su aporte? ¿Por qué no se conocen lo...
# 2    @joseantoniokast  Otra voltereta más. El “Perro Matapacos” ya no...
# 3    @joseantoniokast  Llegaron tarde a la emergencia. Montaron un sh...
# 4    @joseantoniokast  En los cerros de Viña del Mar junto a nuestro ...
# ..                ...                                                ...
# 500     @ClaudioCofr4  Le robaron a OTRO PACO armas... realmente la i...
# 501       @MiTurno143  Cuando JIN salga del servicio militar 😂 #bts #...
# 502    @360radiochile  Alanis Morrissette y su disco unplugged comple...
# 503    @360radiochile  3 horas de música electrónica bailable sin pau...
# 504       @xuxumeitor  A propósito del #ServicioMilitar y el intento ...
#
#                            date  emotion
# 0    May 11, 2024 · 8:11 PM UTC    anger
# 1    May 11, 2024 · 3:52 PM UTC   others
# 2    May 11, 2024 · 2:35 PM UTC    anger
# 3    May 11, 2024 · 1:44 AM UTC    anger
# 4    May 10, 2024 · 7:54 PM UTC  sadness
# ..                          ...      ...
# 500  May 10, 2024 · 2:15 PM UTC    anger
# 501  May 10, 2024 · 6:07 PM UTC   others
# 502  May 10, 2024 · 2:07 PM UTC   others
# 503  May 10, 2024 · 4:22 PM UTC   others
# 504  May 11, 2024 · 8:45 PM UTC   others
#
# [503 rows x 4 columns]

# %%
analyzer2 = create_analyzer(task="sentiment", lang="es")

df = df.dropna(subset=['text'])

def get_main_sentiment(text):
    result = analyzer2.predict(text)
    main_sentiment = max(result.probas, key=result.probas.get)
    
    return main_sentiment

df['sentiment'] = df['text'].apply(get_main_sentiment)
# Out:
# c:\Users\Nicolas\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
df
# Out:
#                  user                                               text  \
# 0    @joseantoniokast  Si un canal de televisión puede establecer la ...
# 1    @DipRepublicanos  ¿Cuál fue su aporte? ¿Por qué no se conocen lo...
# 2    @joseantoniokast  Otra voltereta más. El “Perro Matapacos” ya no...
# 3    @joseantoniokast  Llegaron tarde a la emergencia. Montaron un sh...
# 4    @joseantoniokast  En los cerros de Viña del Mar junto a nuestro ...
# ..                ...                                                ...
# 500     @ClaudioCofr4  Le robaron a OTRO PACO armas... realmente la i...
# 501       @MiTurno143  Cuando JIN salga del servicio militar 😂 #bts #...
# 502    @360radiochile  Alanis Morrissette y su disco unplugged comple...
# 503    @360radiochile  3 horas de música electrónica bailable sin pau...
# 504       @xuxumeitor  A propósito del #ServicioMilitar y el intento ...
#
#                            date  emotion sentiment
# 0    May 11, 2024 · 8:11 PM UTC    anger       NEG
# 1    May 11, 2024 · 3:52 PM UTC   others       NEG
# 2    May 11, 2024 · 2:35 PM UTC    anger       NEG
# 3    May 11, 2024 · 1:44 AM UTC    anger       NEG
# 4    May 10, 2024 · 7:54 PM UTC  sadness       NEG
# ..                          ...      ...       ...
# 500  May 10, 2024 · 2:15 PM UTC    anger       NEG
# 501  May 10, 2024 · 6:07 PM UTC   others       NEU
# 502  May 10, 2024 · 2:07 PM UTC   others       NEU
# 503  May 10, 2024 · 4:22 PM UTC   others       NEU
# 504  May 11, 2024 · 8:45 PM UTC   others       NEG
#
# [503 rows x 5 columns]

# %%
df.to_csv('tweets_modificado.csv', header=False)
